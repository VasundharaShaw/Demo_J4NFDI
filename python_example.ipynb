# %% [markdown]
# ### 🔍 Check the Python Environment
#
# To check the python environment you can use a **terminal** or **notebook**. You can directly use in this ipynb the next cell to try:
#
# 1. Run the following command in a seperate cell to check that `numpy` is installed:
#
#    ```
#    pip show numpy
#    ```
# 2. If it´s not installed use the following command to install it and check again with pip show:
#     ```
#     pip install numpy
#     ```
#
# ✅ If everything worked, you should see version information for NumPy.
#
# ---

# %%
pip show numpy

# %%
pip install numpy

# %%
pip show numpy

# %%
pip uninstall numpy -y

# %%
pip show numpy

# %% [markdown]
# ### Run external python file
# In this task you have to run a external python file in this notebook. You can either create your own file or run the hello_world.py file in the assets directory.
# 1. Run the command: ```! python assets/hello_world.py ```
# 2. Open the file hello_world.py and add an additional line: E.g., print("Greetings to the world")
# 3. Run the command again in a seperate cell: ```! python assets/hello_world.py ```

# %%
! python assets/hello_world.py

# %%
! echo 'print("Greetings to the world")' > assets/hello_world.py

# %%
! python assets/hello_world.py

# %%
! echo 'print("Hello World!")' > assets/hello_world.py

# %%
! python assets/hello_world.py
